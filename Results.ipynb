# %%
# Measure of variability using bootstrapping
# across width and depth individually
# pick 3-5 models to pretrain on imagenet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# results to be interpreted in different scaling dimensions
# based on the analysis pick the models for pre-training
# read a lot of papers and come up with a good story to sell the results

# %% [markdown]
# ### Grouped to Depthwise blocks

# %%
mura = [0.85, 0.834, 0.824, 0.822, 0.792]
rsna = [0.937, 0.934, 0.932, 0.932, 0.929]
chexpert = [0.695, 0.71, 0.717, 0.722, 0.724]

Groups = ['Depthwise', '8', '4', '2', 'Original']
params = [0.728193, 1.564737, 2.937921, 5.684289, 11.177025]

# %%
plt.plot(Groups, params, 'go--')
plt.ylabel("Number of parameters (Millions)")
plt.xlabel("Groups")
plt.savefig("group_params.jpg", dpi=200)

# %%
df = pd.DataFrame()

df['params'] = params
# df['groups'x] = Groups
df['Mura'] = mura
df['RSNA'] = rsna
df['Chexpert'] = chexpert


df = df.set_index('params')

df.plot(style=['ro-','bo-','yo-'], ylim=(0.5, 1))
plt.xlabel('Number of Parameters (Millions)')
plt.ylabel('AUC')
plt.savefig("group_performance.jpg", dpi=200)

# %% [markdown]
# #### MobileNet

# %%
mura_df = pd.read_csv("Scaling_experiments/Mura/mura_mobilenet.csv")
mura_df = mura_df.loc[mura_df.width_x==1.0]

chexpert_df = pd.read_csv("Scaling_experiments/Chexpert/chexpert_mobilenet.csv")
chexpert_df = chexpert_df.loc[chexpert_df.width_x==1.0]

rsna_df = pd.read_csv("/home/rimmanni/experiments/rsna/rsna_mobilenet.csv")
rsna_df = rsna_df.loc[rsna_df.width_x==1.0]

# %%
## Depth wise Scaling
plt.plot(mura_df['params']/1e6, mura_df['val_score'], 'go--')
plt.plot(chexpert_df['params']/1e6, chexpert_df['val_score'], 'ro--')
plt.plot(rsna_df['params']/1e6, rsna_df['val_score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.show()

# %%
mura_df = pd.read_csv("Scaling_experiments/Mura/mura_mobilenet.csv")
mura_df = mura_df.loc[mura_df.depth_x==1.0]

chexpert_df = pd.read_csv("Scaling_experiments/Chexpert/chexpert_mobilenet.csv")
chexpert_df = chexpert_df.loc[chexpert_df.depth_x==1.0]

rsna_df = pd.read_csv("/home/rimmanni/experiments/rsna/rsna_mobilenet.csv")
rsna_df = rsna_df.loc[rsna_df.depth_x==1.0]

# %%
## Width wise Scaling
plt.plot(mura_df['params']/1e6, mura_df['val_score'], 'go--')
plt.plot(chexpert_df['params']/1e6, chexpert_df['val_score'], 'ro--')
plt.plot(rsna_df['params']/1e6, rsna_df['val_score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.show()

# %% [markdown]
# #### Resnet_depthwise

# %%
mura_df = pd.read_csv("Scaling_experiments/Mura/mura_resnet_depthwise.csv")
mura_df = mura_df.loc[mura_df.width_x==1.0]
mura_df = mura_df.sort_values('params')

chexpert_df = pd.read_csv("Scaling_experiments/Chexpert/chexpert_resnet_depthwise.csv")
chexpert_df = chexpert_df.loc[chexpert_df.width_x==1.0]
chexpert_df = chexpert_df.sort_values('params')

rsna_df = pd.read_csv("/home/rimmanni/experiments/rsna/rsna_resnet_depthwise.csv")
rsna_df = rsna_df.loc[rsna_df.width_x==1.0]
rsna_df = rsna_df.sort_values('params')

# %%
mura_df
# Out:
#    index  width_x  depth_x  val_score  params             time_per_epoch
# 5      5      1.0      5.0   0.829103  636353  0 days 00:00:39.889220000
# 2      2      1.0      2.0   0.837213  641281  0 days 00:00:41.040878000
# 1      1      1.0      1.0   0.847418  659329  0 days 00:00:45.084963000
# 4      4      1.0      4.0   0.831386  705217  0 days 00:00:42.495181000
# 3      3      1.0      3.0   0.840171  710145  0 days 00:00:45.032497000
# 0      0      1.0      0.0   0.842868  728193  0 days 00:00:51.636009000

# %%
## Depth wise Scaling
plt.plot(mura_df['params']/1e6, mura_df['val_score'], 'go--')
plt.plot(chexpert_df['params']/1e6, chexpert_df['val_score'], 'ro--')
plt.plot(rsna_df['params']/1e6, rsna_df['val_score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.show()

# %%
mura_df = pd.read_csv("Scaling_experiments/Mura/mura_resnet_depthwise.csv")
mura_df = mura_df.loc[mura_df.depth_x==1.0]
mura_df = mura_df.sort_values('params')

chexpert_df = pd.read_csv("Scaling_experiments/Chexpert/chexpert_resnet_depthwise.csv")
chexpert_df = chexpert_df.loc[chexpert_df.depth_x==1.0]
chexpert_df = chexpert_df.sort_values('params')

rsna_df = pd.read_csv("/home/rimmanni/experiments/rsna/rsna_resnet_depthwise.csv")
rsna_df = rsna_df.loc[rsna_df.depth_x==1.0]
rsna_df = rsna_df.sort_values('params')

# %%
## Width wise Scaling
plt.plot(mura_df['params']/1e6, mura_df['val_score'], 'go--')
plt.plot(chexpert_df['params']/1e6, chexpert_df['val_score'], 'ro--')
plt.plot(rsna_df['params']/1e6, rsna_df['val_score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.show()

# %% [markdown]
# #### Resnet

# %%
mura_df = pd.read_csv("Scaling_experiments/Mura/mura_resnet.csv")
mura_df = mura_df.loc[mura_df.depth_x==7]
mura_df = mura_df.sort_values('params')

chexpert_df = pd.read_csv("Scaling_experiments/Chexpert/chexpert_resnet.csv")
chexpert_df = chexpert_df.loc[chexpert_df.depth_x==7]
chexpert_df = chexpert_df.sort_values('params')

rsna_df = pd.read_csv("/home/rimmanni/experiments/rsna/rsna_resnet.csv")
rsna_df = rsna_df.loc[rsna_df.depth_x==7]
rsna_df = rsna_df.sort_values('params')

# %%
plt.plot(mura_df['params']/1e6, mura_df['val_score'], 'go--')
plt.plot(chexpert_df['params']/1e6, chexpert_df['val_score'], 'ro--')
plt.plot(rsna_df['params']/1e6, rsna_df['val_score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.show()

# %%
mura_df = pd.read_csv("Scaling_experiments/Mura/mura_resnet.csv")
mura_df = mura_df.loc[mura_df.width_x==1.0]
mura_df = mura_df.sort_values('params')

chexpert_df = pd.read_csv("Scaling_experiments/Chexpert/chexpert_resnet.csv")
chexpert_df = chexpert_df.loc[chexpert_df.width_x==1.0]
chexpert_df = chexpert_df.sort_values('params')

rsna_df = pd.read_csv("/home/rimmanni/experiments/rsna/rsna_resnet.csv")
rsna_df = rsna_df.loc[rsna_df.width_x==1.0]
rsna_df = rsna_df.sort_values('params')

# %%
plt.plot(mura_df['params']/1e6, mura_df['val_score'], 'go--')
plt.plot(chexpert_df['params']/1e6, chexpert_df['val_score'], 'ro--')
plt.plot(rsna_df['params']/1e6, rsna_df['val_score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.show()

# %% [markdown]
# ### Bootstrap results

# %% [markdown]
# #### Widthwise

# %%
merged = pd.read_csv("bootstrap/merged.csv")
means = merged.groupby(['model', 'width_x', 'depth_x', 'dataset', 'params'])['score'].mean().reset_index()

mura_df_m = means.loc[(means.dataset=='mura') & (means.model=='mobile') & (means.depth_x==1.0)]
chexpert_df_m = means.loc[(means.dataset=='chexpert') & (means.model=='mobile') & (means.depth_x==1.0)]
rsna_df_m = means.loc[(means.dataset=='rsna') & (means.model=='mobile') & (means.depth_x==1.0)]

# %%
plt.plot(mura_df_m['params']/1e6, mura_df_m['score'], 'go--')
plt.plot(chexpert_df_m['params']/1e6, chexpert_df_m['score'], 'ro--')
plt.plot(rsna_df_m['params']/1e6, rsna_df_m['score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.title("MobileNet")
plt.show()

# %%
mura_df_r = means.loc[(means.dataset=='mura') & (means.model=='resdepth') & (means.depth_x==0.0)]
chexpert_df_r = means.loc[(means.dataset=='chexpert') & (means.model=='resdepth') & (means.depth_x==0.0)]
rsna_df_r = means.loc[(means.dataset=='rsna') & (means.model=='resdepth') & (means.depth_x==0.0)]

# %%
mura_df_r
# Out:
#         model  width_x  depth_x dataset  params     score
# 73   resdepth     0.25      0.0    mura  168353  0.800933
# 91   resdepth     0.50      0.0    mura  388417  0.823092
# 109  resdepth     0.75      0.0    mura  662753  0.824412
# 127  resdepth     1.00      0.0    mura  728193  0.840796

# %%
plt.plot(mura_df_r['params']/1e6, mura_df_r['score'], 'go--')
plt.plot(chexpert_df_r['params']/1e6, chexpert_df_r['score'], 'ro--')
plt.plot(rsna_df_r['params']/1e6, rsna_df_r['score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.title("Resnet-Depthwise")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Width Scaling', fontsize=20)

ax1.plot(mura_df_m['params']/1e6, mura_df_m['score'], 'go--')
ax1.plot(chexpert_df_m['params']/1e6, chexpert_df_m['score'], 'ro--')
ax1.plot(rsna_df_m['params']/1e6, rsna_df_m['score'], 'bo--')
ax1.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
ax1.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax1.set_title("MobileNet")

ax2.plot(mura_df_r['params']/1e6, mura_df_r['score'], 'go--')
ax2.plot(chexpert_df_r['params']/1e6, chexpert_df_r['score'], 'ro--')
ax2.plot(rsna_df_r['params']/1e6, rsna_df_r['score'], 'bo--')
ax2.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
ax2.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax2.set_title("Resnet-Depthwise")

plt.savefig("Width_Scaling.jpg", dpi=200)

# %% [markdown]
# #### Depthwise

# %%
merged = pd.read_csv("bootstrap/merged.csv")
means = merged.groupby(['model', 'width_x', 'depth_x', 'dataset', 'params'])['score'].mean().reset_index()

mura_df_m = means.loc[(means.dataset=='mura') & (means.model=='mobile') & (means.width_x==1.0)]
chexpert_df_m = means.loc[(means.dataset=='chexpert') & (means.model=='mobile') & (means.width_x==1.0)]
rsna_df_m = means.loc[(means.dataset=='rsna') & (means.model=='mobile') & (means.width_x==1.0)]

# %%
plt.plot(mura_df_m['params']/1e6, mura_df_m['score'], 'go--')
plt.plot(chexpert_df_m['params']/1e6, chexpert_df_m['score'], 'ro--')
plt.plot(rsna_df_m['params']/1e6, rsna_df_m['score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.title("MobileNet")
plt.show()

# %%
mura_df_r = means.loc[(means.dataset=='mura') & (means.model=='resdepth') & (means.width_x==1.0)]
mura_df_r = mura_df_r.sort_values('params')
chexpert_df_r = means.loc[(means.dataset=='chexpert') & (means.model=='resdepth') & (means.width_x==1.0)]
chexpert_df_r = chexpert_df_r.sort_values('params')
rsna_df_r = means.loc[(means.dataset=='rsna') & (means.model=='resdepth') & (means.width_x==1.0)]
rsna_df_r = rsna_df_r.sort_values('params')

# %%
plt.plot(mura_df_r['params']/1e6, mura_df_r['score'], 'go--')
plt.plot(chexpert_df_r['params']/1e6, chexpert_df_r['score'], 'ro--')
plt.plot(rsna_df_r['params']/1e6, rsna_df_r['score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.title("Resnet-Depthwise")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Depth Scaling', fontsize=20)

ax1.plot(mura_df_m['params']/1e6, mura_df_m['score'], 'go--')
ax1.plot(chexpert_df_m['params']/1e6, chexpert_df_m['score'], 'ro--')
ax1.plot(rsna_df_m['params']/1e6, rsna_df_m['score'], 'bo--')
ax1.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
ax1.set(xlabel='Parameters in Millions', ylabel='AUC')
ax1.set_title("MobileNet")

ax2.plot(mura_df_r['params']/1e6, mura_df_r['score'], 'go--')
ax2.plot(chexpert_df_r['params']/1e6, chexpert_df_r['score'], 'ro--')
ax2.plot(rsna_df_r['params']/1e6, rsna_df_r['score'], 'bo--')
ax2.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
ax2.set(xlabel='Parameters in Millions', ylabel='AUC')
ax2.set_title("Resnet-Depthwise")

plt.savefig("Depth_Scaling.jpg", dpi=200)

# %% [markdown]
# ### Overall

# %%
merged = pd.read_csv("bootstrap/merged.csv")
means = merged.groupby(['model', 'width_x', 'depth_x', 'dataset', 'params'])['score'].mean().reset_index()
means = means.sort_values('params')

mura_df = means.loc[(means.dataset=='mura') & (means.model=='mobile')]
chexpert_df = means.loc[(means.dataset=='chexpert') & (means.model=='mobile')]
rsna_df = means.loc[(means.dataset=='rsna') & (means.model=='mobile')]

# %%
plt.plot(rsna_df['params']/1e6, rsna_df['score'], '--', label="rsna", )
plt.plot(mura_df['params']/1e6, mura_df['score'], '--', label="mura")
plt.plot(chexpert_df['params']/1e6, chexpert_df['score'], '--', label="chexpert")
plt.axvline(x=0.75, color='grey', ymin=0.05, ymax=0.98, linestyle='dashed')
plt.legend(['rsna', 'mura', 'chexpert'], loc='center right')
plt.show()

# %%
mura_df = means.loc[(means.dataset=='mura') & (means.model=='resdepth')]
chexpert_df = means.loc[(means.dataset=='chexpert') & (means.model=='resdepth')]
rsna_df = means.loc[(means.dataset=='rsna') & (means.model=='resdepth')]

plt.plot(rsna_df['params']/1e6, rsna_df['score'], label="rsna")
plt.plot(mura_df['params']/1e6, mura_df['score'], label="mura")
plt.plot(chexpert_df['params']/1e6, chexpert_df['score'], label="chexpert")
plt.axvline(x=0.38, color='grey', ymin=0.05, ymax=0.98, linestyle='dashed')
# plt.hlines(y, 0, x, linestyle="dashed")
plt.legend(['rsna', 'mura', 'chexpert'], loc='upper right')
plt.show()

# %% [markdown]
# ### Imagenet Trained

# %%
mapping = {'mobilenet_full': 2225153, 'mobilenet_1_0_2': 1147265, 'mobilenet_0_75_0_3': 761545,
      'mobilenet_0_5_0_5': 534305, 'mobilenet_0_25_1': 237593
     }

# %%
ls = np.array([0.448, 0.537, 0.544, 0.553, 0.583])

params = np.array([237593.0, 534305.0, 761545.0, 1147265.0, 2225153.0])

# %%
mura_df = pd.read_csv("imagenet_pretrained/mura_mobilenet.csv")
mura_df = mura_df.groupby(['model', 'dataset'])['score'].mean().reset_index()
mura_df['params'] = mura_df['model'].apply(lambda x: mapping[x])

chexpert_df = pd.read_csv("imagenet_pretrained/chexpert_mobilenet.csv")
chexpert_df = chexpert_df.groupby(['model', 'dataset'])['score'].mean().reset_index()
chexpert_df['params'] = chexpert_df['model'].apply(lambda x: mapping[x])

rsna_df = pd.read_csv("imagenet_pretrained/rsna_mobilenet.csv")
rsna_df = rsna_df.groupby(['model', 'dataset'])['score'].mean().reset_index()
rsna_df['params'] = rsna_df['model'].apply(lambda x: mapping[x])

# %%
plt.plot(mura_df['params']/1e6, mura_df['score'], 'go--')
plt.plot(chexpert_df['params']/1e6, chexpert_df['score'], 'ro--')
plt.plot(rsna_df['params']/1e6, rsna_df['score'], 'bo--')
plt.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
plt.xlabel("Parameters in Millions")
plt.ylabel("AUC")
plt.title("Transfer Learning")
plt.show()

# %%
merged = pd.read_csv("bootstrap/merged.csv")
means = merged.groupby(['model', 'width_x', 'depth_x', 'dataset', 'params'])['score'].mean().reset_index()
means = means.sort_values('params')

mura_df_t = means.loc[(means.dataset=='mura') & (means.model=='mobile')]
chexpert_df_t = means.loc[(means.dataset=='chexpert') & (means.model=='mobile')]
rsna_df_t = means.loc[(means.dataset=='rsna') & (means.model=='mobile')]

# %%
plt.plot(rsna_df['params']/1e6, rsna_df['score'], '--', label="rsna", )
plt.plot(mura_df['params']/1e6, mura_df['score'], '--', label="mura")
plt.plot(chexpert_df['params']/1e6, chexpert_df['score'], '--', label="chexpert")
plt.axvline(x=0.75, color='grey', ymin=0.05, ymax=0.98, linestyle='dashed')
plt.legend(['rsna', 'mura', 'chexpert'], loc='center right')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
# fig.suptitle('With and Without Transfer learning', fontsize=20)

ax1.plot(mura_df_t['params']/1e6, mura_df_t['score'], 'bo--', markersize=4)
ax1.plot(chexpert_df_t['params']/1e6, chexpert_df_t['score'], 'go--', markersize=4)
ax1.plot(rsna_df_t['params']/1e6, rsna_df_t['score'], 'ro--', markersize=4)
ax1.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
ax1.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax1.set_title("Without Transfer Learning")

ax2.plot(mura_df['params']/1e6, mura_df['score'], 'bo--', markersize=4)
ax2.plot(chexpert_df['params']/1e6, chexpert_df['score'], 'go--', markersize=4)
ax2.plot(rsna_df['params']/1e6, rsna_df['score'], 'ro--', markersize=4)
ax2.plot(params/1e6, ls, markersize=5)
ax2.legend(['Mura', 'Chexpert', 'RSNA', 'Imagenet Accuracy'], loc='lower right')
ax2.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax2.set_title("Transfer Learning")
# Out:
# Text(0.5,1,'Transfer Learning')

# %%
fig, (ax2) = plt.subplots(1, 1, figsize=(7, 5))

ax2.plot(mura_df['params']/1e6, mura_df['score'], 'bo--', markersize=4)
ax2.plot(chexpert_df['params']/1e6, chexpert_df['score'], 'go--', markersize=4)
ax2.plot(rsna_df['params']/1e6, rsna_df['score'], 'ro--', markersize=4)
ax2.plot(params/1e6, ls, markersize=5)
ax2.legend(['Mura', 'Chexpert', 'RSNA', 'Imagenet Accuracy'], loc='lower right')
ax2.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax2.set_title("MobileNet variants with Transfer Learning")

plt.savefig("TransferLearning_MobileNet.jpg", dpi=200)

# %%
mapping = {'resnet_full': 728193, 'resnet_0_75_4': 649361, 'resnet_0_5_full_depth': 388417,
      'resnet_0_5_4': 382049, 'resnet_0_25_full_depth': 168353
     }

# %%
sorted(list(mapping.values()))
# Out:
# [168353, 382049, 388417, 649361, 728193]

# %%
ls2 = np.array([0.341, 0.422, 0.441, 0.474, 0.523])

params2 = np.array([168353, 382049, 388417, 649361, 728193])

# %%
merged = pd.read_csv("bootstrap/merged.csv")
means = merged.groupby(['model', 'width_x', 'depth_x', 'dataset', 'params'])['score'].mean().reset_index()
means = means.sort_values('params')

mura_df_t = means.loc[(means.dataset=='mura') & (means.model=='resdepth')]
chexpert_df_t = means.loc[(means.dataset=='chexpert') & (means.model=='resdepth')]
rsna_df_t = means.loc[(means.dataset=='rsna') & (means.model=='resdepth')]

# %%
mura_df_r = pd.read_csv("imagenet_pretrained/mura_resnet.csv")
mura_df_r = mura_df_r.groupby(['model', 'dataset'])['score'].mean().reset_index()
mura_df_r['params'] = mura_df_r['model'].apply(lambda x: mapping[x])

chexpert_df_r = pd.read_csv("imagenet_pretrained/chexpert_resnet.csv")
chexpert_df_r = chexpert_df_r.groupby(['model', 'dataset'])['score'].mean().reset_index()
chexpert_df_r['params'] = chexpert_df_r['model'].apply(lambda x: mapping[x])

rsna_df_r = pd.read_csv("imagenet_pretrained/rsna_resnet.csv")
rsna_df_r = rsna_df_r.groupby(['model', 'dataset'])['score'].mean().reset_index()
rsna_df_r['params'] = rsna_df_r['model'].apply(lambda x: mapping[x])

# %%
# new_row1 = {'model': 'original', 'dataset': 'mura', 'score': 0.888, 'params': 1110000}
# mura_df = mura_df.append(new_row1, ignore_index=True)

# new_row2 = {'model': 'original', 'dataset': 'chexpert', 'score': 0.707, 'params': 1110000}
# chexpert_df = chexpert_df.append(new_row2, ignore_index=True)

# new_row3 = {'model': 'original', 'dataset': 'rsna', 'score': 0.963, 'params': 1110000}
# rsna_df = rsna_df.append(new_row3, ignore_index=True)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
# fig.suptitle('With and Without Transfer learning', fontsize=20)

ax1.plot(mura_df_t['params']/1e6, mura_df_t['score'], 'bo--', markersize=4)
ax1.plot(chexpert_df_t['params']/1e6, chexpert_df_t['score'], 'go--', markersize=4)
ax1.plot(rsna_df_t['params']/1e6, rsna_df_t['score'], 'ro--', markersize=4)
ax1.legend(['Mura', 'Chexpert', 'RSNA'], loc='center right')
ax1.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax1.set_title("Without Transfer Learning")

ax2.plot(mura_df['params']/1e6, mura_df['score'], 'bo--', markersize=4)
ax2.plot(chexpert_df['params']/1e6, chexpert_df['score'], 'go--', markersize=4)
ax2.plot(rsna_df['params']/1e6, rsna_df['score'], 'ro--', markersize=4)
ax2.plot(params/1e6, ls)
ax2.legend(['Mura', 'Chexpert', 'RSNA', 'Imagenet Accuracy'], loc='lower right')
ax2.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax2.set_title("Transfer Learning")
# Out:
# Text(0.5,1,'Transfer Learning')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Transfer learning', fontsize=20)

ax1.plot(mura_df['params']/1e6, mura_df['score'], 'bo--', markersize=4)
ax1.plot(chexpert_df['params']/1e6, chexpert_df['score'], 'go--', markersize=4)
ax1.plot(rsna_df['params']/1e6, rsna_df['score'], 'ro--', markersize=4)
ax1.plot(params/1e6, ls, markersize=5)
ax1.legend(['Mura', 'Chexpert', 'RSNA', 'Imagenet Accuracy'], loc='lower right')
ax1.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax1.set_title("MobileNet variants")

ax2.plot(mura_df_r['params']/1e6, mura_df_r['score'], 'bo--', markersize=4)
ax2.plot(chexpert_df_r['params']/1e6, chexpert_df_r['score'], 'go--', markersize=4)
ax2.plot(rsna_df_r['params']/1e6, rsna_df_r['score'], 'ro--', markersize=4)
ax2.plot(params2/1e6, ls2)
ax2.legend(['Mura', 'Chexpert', 'RSNA', 'Imagenet Accuracy'], loc='lower right')
ax2.set(xlabel='Parameters in Millions"', ylabel='AUC')
ax2.set_title("ResNet variants")

plt.savefig("TransferLearning.jpg", dpi=200)
